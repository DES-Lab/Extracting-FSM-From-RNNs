# %%
# Imports
from aalpy.SULs import MealySUL
from aalpy.oracles import StatePrefixEqOracle

from DataProcessing import get_coffee_machine, generate_data_from_automaton
from TrainAndExtract import train_RNN_on_mealy_data, extract_finite_state_transducer

# %%
# Get coffee machine model
coffee_machine = get_coffee_machine()

# Get its input and output alphabet
input_al = coffee_machine.get_input_alphabet()
output_al = {output for state in coffee_machine.states for output in state.output_fun.values()}

# %%
# Generate training data from coffee machine FSM
train_seq, train_labels = generate_data_from_automaton(coffee_machine, input_al,
                                                       num_examples=10000, lens=(2, 5, 8, 10))

training_data = (train_seq, train_labels)

# %%
# Train 2 RNNs with the data
rnn_1 = train_RNN_on_mealy_data(coffee_machine, data=training_data, ex_name='coffee_1')
rnn_2 = train_RNN_on_mealy_data(coffee_machine, data=training_data, ex_name=f'coffee_2')
# Out:
# Starting train
# Epoch 0: Accuracy 0.96289, Avg. Loss 8.93819 Validation Accuracy 0.9575
# Epoch 1: Accuracy 0.96602, Avg. Loss 3.93633 Validation Accuracy 0.9585
# Epoch 2: Accuracy 0.97726, Avg. Loss 2.88321 Validation Accuracy 0.9765
# Epoch 3: Accuracy 0.98363, Avg. Loss 2.01579 Validation Accuracy 0.983
# Epoch 4: Accuracy 0.98326, Avg. Loss 1.97149 Validation Accuracy 0.9815
# Epoch 5: Accuracy 0.98551, Avg. Loss 1.7448 Validation Accuracy 0.982
# Epoch 6: Accuracy 0.98876, Avg. Loss 1.46309 Validation Accuracy 0.9885
# Epoch 7: Accuracy 0.99475, Avg. Loss 1.00747 Validation Accuracy 0.9955
# Epoch 8: Accuracy 0.99925, Avg. Loss 0.42133 Validation Accuracy 0.9985
# Epoch 9: Accuracy 0.99988, Avg. Loss 0.11914 Validation Accuracy 1.0
# Epoch 10: Accuracy 1.0, Avg. Loss 0.05698 Validation Accuracy 1.0
# Epoch 11: Accuracy 1.0, Avg. Loss 0.02926 Validation Accuracy 1.0
# Epoch 12: Accuracy 1.0, Avg. Loss 0.01781 Validation Accuracy 1.0
# Done training!
# Starting train
# Epoch 0: Accuracy 0.95815, Avg. Loss 9.06551 Validation Accuracy 0.956
# Epoch 1: Accuracy 0.97864, Avg. Loss 3.95867 Validation Accuracy 0.974
# Epoch 2: Accuracy 0.98276, Avg. Loss 2.21247 Validation Accuracy 0.979
# Epoch 3: Accuracy 0.98238, Avg. Loss 1.75971 Validation Accuracy 0.977
# Epoch 4: Accuracy 0.98226, Avg. Loss 1.70373 Validation Accuracy 0.977
# Epoch 5: Accuracy 0.98313, Avg. Loss 1.66131 Validation Accuracy 0.978
# Epoch 6: Accuracy 0.98338, Avg. Loss 1.54795 Validation Accuracy 0.979
# Epoch 7: Accuracy 0.98376, Avg. Loss 1.4444 Validation Accuracy 0.979
# Epoch 8: Accuracy 0.98376, Avg. Loss 1.35395 Validation Accuracy 0.9785
# Epoch 9: Accuracy 0.98488, Avg. Loss 1.24819 Validation Accuracy 0.981
# Epoch 10: Accuracy 0.98788, Avg. Loss 1.16202 Validation Accuracy 0.984
# Epoch 11: Accuracy 0.99738, Avg. Loss 0.5989 Validation Accuracy 0.993
# Epoch 12: Accuracy 0.99813, Avg. Loss 0.24298 Validation Accuracy 0.994
# Epoch 13: Accuracy 0.999, Avg. Loss 0.17749 Validation Accuracy 0.9945
# Epoch 14: Accuracy 0.999, Avg. Loss 0.15784 Validation Accuracy 0.9945
# Epoch 15: Accuracy 0.99913, Avg. Loss 0.14917 Validation Accuracy 0.9945
# Epoch 16: Accuracy 0.99913, Avg. Loss 0.14196 Validation Accuracy 0.9945
# Epoch 17: Accuracy 0.99913, Avg. Loss 0.13654 Validation Accuracy 0.9945
# Epoch 18: Accuracy 0.99913, Avg. Loss 0.13077 Validation Accuracy 0.9945
# Epoch 19: Accuracy 0.99913, Avg. Loss 0.1236 Validation Accuracy 0.9945
# Epoch 20: Accuracy 0.99913, Avg. Loss 0.11338 Validation Accuracy 0.9945
# Epoch 21: Accuracy 0.99913, Avg. Loss 0.09725 Validation Accuracy 0.9945
# Epoch 22: Accuracy 0.99975, Avg. Loss 0.07408 Validation Accuracy 0.9955
# Epoch 23: Accuracy 0.99975, Avg. Loss 0.05333 Validation Accuracy 0.9955
# Epoch 24: Accuracy 0.9945, Avg. Loss 0.04909 Validation Accuracy 0.9895
# Epoch 25: Accuracy 0.99788, Avg. Loss 0.10321 Validation Accuracy 0.994
# Epoch 26: Accuracy 0.99975, Avg. Loss 0.02944 Validation Accuracy 0.996
# Epoch 27: Accuracy 1.0, Avg. Loss 0.02169 Validation Accuracy 0.999
# Epoch 28: Accuracy 0.99913, Avg. Loss 0.04918 Validation Accuracy 0.9975
# Epoch 29: Accuracy 1.0, Avg. Loss 0.01238 Validation Accuracy 0.999
# Epoch 30: Accuracy 1.0, Avg. Loss 0.01031 Validation Accuracy 0.999
# Epoch 31: Accuracy 1.0, Avg. Loss 0.00949 Validation Accuracy 0.999
# Epoch 32: Accuracy 1.0, Avg. Loss 0.00894 Validation Accuracy 0.999
# Epoch 33: Accuracy 1.0, Avg. Loss 0.00849 Validation Accuracy 0.999
# Epoch 34: Accuracy 1.0, Avg. Loss 0.00809 Validation Accuracy 0.9995
# Epoch 35: Accuracy 1.0, Avg. Loss 0.00766 Validation Accuracy 0.9995
# Epoch 36: Accuracy 1.0, Avg. Loss 0.00726 Validation Accuracy 0.9995
# Epoch 37: Accuracy 1.0, Avg. Loss 0.00687 Validation Accuracy 0.999
# Epoch 38: Accuracy 1.0, Avg. Loss 0.00665 Validation Accuracy 0.999
# Epoch 39: Accuracy 1.0, Avg. Loss 0.0064 Validation Accuracy 0.999
# Epoch 40: Accuracy 1.0, Avg. Loss 0.00615 Validation Accuracy 0.999
# Epoch 41: Accuracy 1.0, Avg. Loss 0.00603 Validation Accuracy 0.999
# Epoch 42: Accuracy 1.0, Avg. Loss 0.00594 Validation Accuracy 0.999
# Epoch 43: Accuracy 1.0, Avg. Loss 0.00587 Validation Accuracy 0.9995
# Epoch 44: Accuracy 1.0, Avg. Loss 0.0058 Validation Accuracy 0.9995
# Epoch 45: Accuracy 1.0, Avg. Loss 0.00573 Validation Accuracy 0.9995
# Epoch 46: Accuracy 1.0, Avg. Loss 0.00563 Validation Accuracy 0.9995
# Epoch 47: Accuracy 1.0, Avg. Loss 0.00557 Validation Accuracy 0.9995
# Epoch 48: Accuracy 1.0, Avg. Loss 0.0055 Validation Accuracy 0.9995
# Epoch 49: Accuracy 1.0, Avg. Loss 0.00542 Validation Accuracy 0.9995
# Epoch 50: Accuracy 1.0, Avg. Loss 0.00534 Validation Accuracy 0.9995
# Epoch 51: Accuracy 1.0, Avg. Loss 0.00529 Validation Accuracy 0.9995
# Epoch 52: Accuracy 1.0, Avg. Loss 0.00525 Validation Accuracy 0.9995
# Epoch 53: Accuracy 1.0, Avg. Loss 0.00521 Validation Accuracy 0.9995
# Epoch 54: Accuracy 1.0, Avg. Loss 0.00518 Validation Accuracy 0.9995
# Epoch 55: Accuracy 1.0, Avg. Loss 0.00516 Validation Accuracy 0.9995
# Epoch 56: Accuracy 1.0, Avg. Loss 0.00513 Validation Accuracy 0.9995
# Epoch 57: Accuracy 1.0, Avg. Loss 0.00511 Validation Accuracy 0.9995
# Epoch 58: Accuracy 1.0, Avg. Loss 0.00509 Validation Accuracy 0.9995
# Epoch 59: Accuracy 1.0, Avg. Loss 0.00508 Validation Accuracy 0.9995
# Epoch 60: Accuracy 1.0, Avg. Loss 0.00507 Validation Accuracy 1.0
# Epoch 61: Accuracy 1.0, Avg. Loss 0.00505 Validation Accuracy 1.0
# Epoch 62: Accuracy 1.0, Avg. Loss 0.00504 Validation Accuracy 1.0
# Done training!

# %%
# Extract automata from each RNN
learned_automaton_1 = extract_finite_state_transducer(rnn_1, input_al, output_al, max_learning_rounds=25)
learned_automaton_2 = extract_finite_state_transducer(rnn_2, input_al, output_al, max_learning_rounds=25)
# Out:
# Hypothesis 1: 2 states.
# Hypothesis 2: 5 states.
# Hypothesis 3: 6 states.
# Hypothesis 4: 7 states.
# Hypothesis 5: 8 states.
# Hypothesis 6: 10 states.
# Hypothesis 7: 13 states.
# Hypothesis 8: 16 states.
# Hypothesis 9: 18 states.
# Hypothesis 10: 21 states.
# Hypothesis 11: 22 states.
# Hypothesis 12: 24 states.
# Hypothesis 13: 25 states.
# Hypothesis 14: 26 states.
# Hypothesis 15: 27 states.
# Hypothesis 16: 46 states.
# Hypothesis 17: 48 states.
# Hypothesis 18: 49 states.
# Hypothesis 19: 54 states.
# Hypothesis 20: 58 states.
# Hypothesis 21: 60 states.
# Hypothesis 22: 64 states.
# Hypothesis 23: 68 states.
# Hypothesis 24: 71 states.
# Hypothesis 25: 76 states.
# -----------------------------------
# Learning Finished.
# Learning Rounds:  26
# Number of states: 76
# Time (in seconds)
#   Total                : 6.84
#   Learning algorithm   : 5.15
#   Conformance checking : 1.69
# Learning Algorithm
#  # Membership Queries  : 8965
#  # Steps               : 143430
# Equivalence Query
#  # Membership Queries  : 1449
#  # Steps               : 41860
# -----------------------------------
# Hypothesis 1: 2 states.
# Hypothesis 2: 5 states.
# Hypothesis 3: 6 states.
# -----------------------------------
# Learning Finished.
# Learning Rounds:  3
# Number of states: 6
# Time (in seconds)
#   Total                : 0.96
#   Learning algorithm   : 0.02
#   Conformance checking : 0.94
# Learning Algorithm
#  # Membership Queries  : 159
#  # Steps               : 591
# Equivalence Query
#  # Membership Queries  : 900
#  # Steps               : 23672
# -----------------------------------

# %%
sul = MealySUL(learned_automaton_2)
sul2 = MealySUL(learned_automaton_1)

# Define eq. oracle used for conformance-checking (learning-based testing)
eq_oracle = StatePrefixEqOracle(input_al, sul, walks_per_state=100, walk_len=20)

# %%
# Find and print cases of non-conformance
cex_set = set()
for i in range(200):
    cex = eq_oracle.find_cex(learned_automaton_1)
    if cex:
        if tuple(cex) not in cex_set:
            print('--------------------------------------------------------------------------')
            print('Case of Non-Conformance between Automata: ', cex)
            print('Model 1  : ', sul.query(cex))
            print('Model 2  : ', sul2.query(cex))
        cex_set.add(tuple(cex))
# Out:
#  'star', 'star', 'star']
# --------------------------------------------------------------------------
# Case of Non-Conformance between Automata:  ('pod', 'water', 'water', 'water', 'water', 'water', 'button', 'clean', 'water', 'water', 'pod', 'pod', 'water', 'water', 'water', 'button', 'water')
# Model 1  :  ['check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'check', 'check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'coffee']
# Model 2  :  ['check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'star', 'star', 'star', 'star', 'star', 'check', 'check', 'coffee', 'star']
# --------------------------------------------------------------------------
# Case of Non-Conformance between Automata:  ('pod', 'water', 'water', 'water', 'water', 'water', 'water', 'button', 'clean', 'pod', 'pod', 'water', 'clean')
# Model 1  :  ['check', 'check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'check', 'check', 'check', 'check']
# Model 2  :  ['check', 'check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'star', 'star', 'star', 'star', 'star']
# --------------------------------------------------------------------------
# Case of Non-Conformance between Automata:  ('pod', 'water', 'water', 'water', 'water', 'water', 'button', 'clean', 'water', 'pod', 'pod')
# Model 1  :  ['check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'check', 'check', 'check']
# Model 2  :  ['check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'star', 'star', 'star']
# --------------------------------------------------------------------------
# Case of Non-Conformance between Automata:  ('pod', 'water', 'water', 'water', 'water', 'water', 'button', 'clean', 'water', 'water', 'water', 'water', 'clean')
# Model 1  :  ['check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'check', 'check', 'check', 'check', 'check']
# Model 2  :  ['check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'star', 'star', 'star', 'star', 'star']
# --------------------------------------------------------------------------
# Case of Non-Conformance between Automata:  ('pod', 'water', 'water', 'water', 'water', 'water', 'water', 'button', 'clean', 'pod', 'water', 'pod', 'pod')
# Model 1  :  ['check', 'check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'check', 'check', 'check', 'check']
# Model 2  :  ['check', 'check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'star', 'star', 'star', 'star', 'star']
# --------------------------------------------------------------------------
# Case of Non-Conformance between Automata:  ('pod', 'water', 'water', 'water', 'water', 'water', 'water', 'button', 'clean', 'pod', 'water')
# Model 1  :  ['check', 'check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'check', 'check']
# Model 2  :  ['check', 'check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'star', 'star', 'star']
# --------------------------------------------------------------------------
# Case of Non-Conformance between Automata:  ('pod', 'water', 'water', 'water', 'water', 'water', 'water', 'button', 'clean', 'pod', 'pod', 'pod', 'pod')
# Model 1  :  ['check', 'check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'check', 'check', 'check', 'check']
# Model 2  :  ['check', 'check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'star', 'star', 'star', 'star', 'star']
# --------------------------------------------------------------------------
# Case of Non-Conformance between Automata:  ('pod', 'water', 'water', 'water', 'water', 'water', 'button', 'clean', 'water', 'water', 'pod', 'pod')
# Model 1  :  ['check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'check', 'check', 'check', 'check']
# Model 2  :  ['check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'star', 'star', 'star', 'star']
# --------------------------------------------------------------------------
# Case of Non-Conformance between Automata:  ('pod', 'water', 'water', 'water', 'water', 'button', 'clean', 'water', 'water', 'water')
# Model 1  :  ['check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'check', 'check', 'check']
# Model 2  :  ['check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'check', 'star', 'star']
# --------------------------------------------------------------------------
# Case of Non-Conformance between Automata:  ('pod', 'water', 'water', 'water', 'water', 'water', 'water', 'button', 'clean', 'pod', 'water', 'water', 'pod', 'button')
# Model 1  :  ['check', 'check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'check', 'check', 'check', 'check', 'coffee']
# Model 2  :  ['check', 'check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'star', 'star', 'star', 'star', 'star', 'star']
# --------------------------------------------------------------------------
# Case of Non-Conformance between Automata:  ('pod', 'water', 'water', 'water', 'water', 'water', 'water', 'button', 'clean', 'pod', 'pod', 'water', 'water')
# Model 1  :  ['check', 'check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'check', 'check', 'check', 'check']
# Model 2  :  ['check', 'check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'star', 'star', 'star', 'star', 'star']
# --------------------------------------------------------------------------
# Case of Non-Conformance between Automata:  ('pod', 'water', 'water', 'water', 'water', 'button', 'clean', 'water', 'pod', 'button', 'pod')
# Model 1  :  ['check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'check', 'check', 'coffee', 'coffee']
# Model 2  :  ['check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'check', 'check', 'star', 'star']
# --------------------------------------------------------------------------
# Case of Non-Conformance between Automata:  ('pod', 'water', 'water', 'water', 'water', 'water', 'button', 'clean', 'water', 'water', 'pod', 'clean')
# Model 1  :  ['check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'check', 'check', 'check', 'check']
# Model 2  :  ['check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'star', 'star', 'star', 'star']
# --------------------------------------------------------------------------
# Case of Non-Conformance between Automata:  ('pod', 'water', 'water', 'water', 'water', 'water', 'button', 'clean', 'water', 'water', 'pod', 'water', 'button')
# Model 1  :  ['check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'check', 'check', 'check', 'check', 'coffee']
# Model 2  :  ['check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'star', 'star', 'star', 'star', 'star']
# --------------------------------------------------------------------------
# Case of Non-Conformance between Automata:  ('pod', 'water', 'water', 'water', 'water', 'water', 'button', 'clean', 'water', 'pod', 'pod', 'water', 'button')
# Model 1  :  ['check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'check', 'check', 'check', 'check', 'coffee']
# Model 2  :  ['check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'star', 'star', 'star', 'check', 'star']
# --------------------------------------------------------------------------
# Case of Non-Conformance between Automata:  ('pod', 'water', 'water', 'water', 'water', 'button', 'water')
# Model 1  :  ['check', 'check', 'check', 'check', 'check', 'coffee', 'coffee']
# Model 2  :  ['check', 'check', 'check', 'check', 'check', 'coffee', 'star']
# --------------------------------------------------------------------------
# Case of Non-Conformance between Automata:  ('pod', 'water', 'water', 'water', 'water', 'water', 'button', 'clean', 'water', 'water', 'pod', 'pod', 'water', 'pod')
# Model 1  :  ['check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'check', 'check', 'check', 'check', 'check', 'check']
# Model 2  :  ['check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'star', 'star', 'star', 'star', 'star', 'star']
# --------------------------------------------------------------------------
# Case of Non-Conformance between Automata:  ('pod', 'water', 'water', 'water', 'water', 'water', 'water', 'button', 'clean', 'pod', 'pod', 'clean')
# Model 1  :  ['check', 'check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'check', 'check', 'check']
# Model 2  :  ['check', 'check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'star', 'star', 'star', 'star']
# --------------------------------------------------------------------------
# Case of Non-Conformance between Automata:  ('pod', 'water', 'water', 'water', 'water', 'water', 'button', 'clean', 'water')
# Model 1  :  ['check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'check']
# Model 2  :  ['check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'star']
# --------------------------------------------------------------------------
# Case of Non-Conformance between Automata:  ('pod', 'water', 'water', 'water', 'water', 'water', 'water', 'button', 'clean', 'pod', 'pod', 'pod', 'water', 'pod', 'button', 'clean')
# Model 1  :  ['check', 'check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'check']
# Model 2  :  ['check', 'check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'star', 'star', 'star', 'star', 'star', 'star', 'star', 'star']
# --------------------------------------------------------------------------
# Case of Non-Conformance between Automata:  ('pod', 'water', 'water', 'water', 'water', 'water', 'button', 'pod')
# Model 1  :  ['check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'coffee']
# Model 2  :  ['check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'star']
# --------------------------------------------------------------------------
# Case of Non-Conformance between Automata:  ('pod', 'water', 'water', 'water', 'water', 'water', 'button', 'clean', 'water', 'water', 'pod', 'water', 'water')
# Model 1  :  ['check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'check', 'check', 'check', 'check', 'check']
# Model 2  :  ['check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'star', 'star', 'star', 'star', 'star']
# --------------------------------------------------------------------------
# Case of Non-Conformance between Automata:  ('pod', 'water', 'water', 'water', 'water', 'water', 'button', 'clean', 'water', 'pod', 'button', 'pod')
# Model 1  :  ['check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'check', 'check', 'coffee', 'coffee']
# Model 2  :  ['check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'star', 'star', 'star', 'star']
# --------------------------------------------------------------------------
# Case of Non-Conformance between Automata:  ('pod', 'water', 'water', 'water', 'water', 'water', 'water', 'button', 'clean', 'pod', 'pod', 'pod', 'water')
# Model 1  :  ['check', 'check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'check', 'check', 'check', 'check']
# Model 2  :  ['check', 'check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'star', 'star', 'star', 'star', 'star']
# --------------------------------------------------------------------------
# Case of Non-Conformance between Automata:  ('pod', 'water', 'water', 'water', 'water', 'water', 'water', 'button', 'clean', 'pod', 'water', 'clean')
# Model 1  :  ['check', 'check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'check', 'check', 'check']
# Model 2  :  ['check', 'check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'star', 'star', 'star', 'star']
# --------------------------------------------------------------------------
# Case of Non-Conformance between Automata:  ('pod', 'water', 'water', 'water', 'water', 'water', 'water', 'button', 'clean', 'pod', 'pod', 'pod', 'water', 'pod', 'button', 'pod')
# Model 1  :  ['check', 'check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'coffee']
# Model 2  :  ['check', 'check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'star', 'star', 'star', 'star', 'star', 'star', 'star', 'star']
# --------------------------------------------------------------------------
# Case of Non-Conformance between Automata:  ('pod', 'water', 'water', 'water', 'water', 'water', 'water', 'button', 'clean', 'pod', 'water', 'pod', 'water', 'water', 'button', 'pod')
# Model 1  :  ['check', 'check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'coffee']
# Model 2  :  ['check', 'check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'star', 'star', 'star', 'star', 'star', 'check', 'coffee', 'star']
# --------------------------------------------------------------------------
# Case of Non-Conformance between Automata:  ('pod', 'water', 'water', 'water', 'water', 'water', 'water', 'button', 'clean', 'pod', 'water', 'water', 'button')
# Model 1  :  ['check', 'check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'check', 'check', 'check', 'coffee']
# Model 2  :  ['check', 'check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'star', 'star', 'star', 'star', 'star']
# --------------------------------------------------------------------------
# Case of Non-Conformance between Automata:  ('pod', 'water', 'water', 'water', 'water', 'button', 'clean', 'water', 'pod', 'button', 'clean', 'clean')
# Model 1  :  ['check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'check', 'check', 'coffee', 'check', 'check']
# Model 2  :  ['check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'check', 'check', 'star', 'star', 'star']
# --------------------------------------------------------------------------
# Case of Non-Conformance between Automata:  ('pod', 'water', 'water', 'water', 'water', 'water', 'water', 'button', 'clean', 'pod', 'water', 'water', 'pod', 'clean')
# Model 1  :  ['check', 'check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'check', 'check', 'check', 'check', 'check']
# Model 2  :  ['check', 'check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'star', 'star', 'star', 'star', 'star', 'star']
# --------------------------------------------------------------------------
# Case of Non-Conformance between Automata:  ('pod', 'water', 'water', 'water', 'water', 'water', 'button', 'clean', 'water', 'water', 'clean', 'water')
# Model 1  :  ['check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'check', 'check', 'check', 'check']
# Model 2  :  ['check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'star', 'star', 'star', 'star']
# --------------------------------------------------------------------------
# Case of Non-Conformance between Automata:  ('pod', 'water', 'water', 'water', 'water', 'water', 'water', 'button', 'clean', 'pod')
# Model 1  :  ['check', 'check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'check']
# Model 2  :  ['check', 'check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'star', 'star']
# --------------------------------------------------------------------------
# Case of Non-Conformance between Automata:  ('pod', 'water', 'water', 'water', 'water', 'water', 'button', 'water')
# Model 1  :  ['check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'coffee']
# Model 2  :  ['check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'star']
# --------------------------------------------------------------------------
# Case of Non-Conformance between Automata:  ('pod', 'water', 'water', 'water', 'water', 'water', 'water', 'button', 'clean', 'pod', 'pod', 'water', 'pod', 'pod', 'pod', 'button', 'clean')
# Model 1  :  ['check', 'check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'check']
# Model 2  :  ['check', 'check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'star', 'star', 'star', 'star', 'star', 'star', 'check', 'coffee', 'star']
# --------------------------------------------------------------------------
# Case of Non-Conformance between Automata:  ('pod', 'water', 'water', 'water', 'water', 'water', 'water', 'button', 'clean')
# Model 1  :  ['check', 'check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'check']
# Model 2  :  ['check', 'check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'star']
# --------------------------------------------------------------------------
# Case of Non-Conformance between Automata:  ('pod', 'water', 'water', 'water', 'water', 'water', 'water', 'button', 'clean', 'pod', 'pod')
# Model 1  :  ['check', 'check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'check', 'check']
# Model 2  :  ['check', 'check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'star', 'star', 'star']
# --------------------------------------------------------------------------
# Case of Non-Conformance between Automata:  ('pod', 'water', 'water', 'water', 'water', 'water', 'button', 'clean', 'water', 'pod', 'pod', 'button')
# Model 1  :  ['check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'check', 'check', 'check', 'coffee']
# Model 2  :  ['check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'star', 'star', 'star', 'star']
# --------------------------------------------------------------------------
# Case of Non-Conformance between Automata:  ('pod', 'water', 'water', 'water', 'water', 'water', 'water', 'button', 'clean', 'pod', 'water', 'water', 'water')
# Model 1  :  ['check', 'check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'check', 'check', 'check', 'check']
# Model 2  :  ['check', 'check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'star', 'star', 'star', 'star', 'star']
# --------------------------------------------------------------------------
# Case of Non-Conformance between Automata:  ('pod', 'water', 'water', 'water', 'water', 'water', 'water', 'button', 'clean', 'pod', 'water', 'button', 'water')
# Model 1  :  ['check', 'check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'check', 'check', 'coffee', 'coffee']
# Model 2  :  ['check', 'check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'star', 'star', 'star', 'star', 'star']
# --------------------------------------------------------------------------
# Case of Non-Conformance between Automata:  ('pod', 'water', 'water', 'water', 'water', 'water', 'water', 'button', 'clean', 'pod', 'pod', 'water', 'pod', 'pod', 'pod', 'button', 'button')
# Model 1  :  ['check', 'check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'coffee']
# Model 2  :  ['check', 'check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'star', 'star', 'star', 'star', 'star', 'star', 'check', 'coffee', 'star']
# --------------------------------------------------------------------------
# Case of Non-Conformance between Automata:  ('pod', 'water', 'water', 'water', 'water', 'button', 'clean', 'water', 'water', 'pod', 'button', 'button')
# Model 1  :  ['check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'check', 'check', 'check', 'coffee', 'coffee']
# Model 2  :  ['check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'check', 'star', 'star', 'star', 'star']
# --------------------------------------------------------------------------
# Case of Non-Conformance between Automata:  ('pod', 'water', 'water', 'water', 'water', 'water', 'button', 'clean', 'water', 'water', 'clean', 'pod', 'water')
# Model 1  :  ['check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'check', 'check', 'check', 'check', 'check']
# Model 2  :  ['check', 'check', 'check', 'check', 'check', 'check', 'coffee', 'check', 'star', 'star', 'star', 'star', 'star']
